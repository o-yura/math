# %% [markdown]
# ### Теория вероятностей и математическая статистика. Урок 1.

# %% [markdown]
# #### 1. Из колоды в 52 карты извлекаются случайным образом 4 карты. Найти вероятность того, что все карты – крести. Найти вероятность, что среди этих карт окажется хотя бы один туз.

# %% [markdown]
# Количество сочетаний из 4-х карт:
# $$C_{52}^{4}=\frac{52!}{48!*4!}=\frac{49*50*51*52}{2*3*4}=\frac{49*25*51*13}{3}=\frac{812175}{3}=270725$$

# %% [markdown]
# Количество сочетаний - 4 крести:
# $$C_{13}^{4}=\frac{13!}{9!*4!}=\frac{10*11*12*13}{2*3*4}=5*11*13=715$$

# %% [markdown]
# Вероятность 4 крести:
# $$P=\frac{C_{52}^{4}}{C_{13}^{4}}=\frac{715}{270725}=0,002641056$$

# %% [markdown]
# Количество сочетаний 4 крести с тузом:
# $$C_{12}^{3}=\frac{12!}{9!*3!}=\frac{10*11*12}{2*3}=10*11*2=220$$

# %% [markdown]
# Вероятность 4 крести с тузом:
# $$P=\frac{C_{52}^{4}}{C_{12}^{3}}=\frac{220}{270725}=0,000812633$$

# %% [markdown]
# #### 2. На входной двери подъезда установлен кодовый замок, содержащий десять кнопок с цифрами от 0 до 9. Код содержит три цифры, которые нужно нажать одновременно. Какова вероятность того, что человек, не знающий код, откроет дверь с первой попытки?

# %% [markdown]
# Количество сочетаний:
#     $$C_{10}^{3}=\frac{10!}{7!*3!}=\frac{8*9*10}{2*3}=8*3*5=120$$

# %% [markdown]
# Вероятность угадать с первого раза:
# $$P=\frac{1}{C_{10}^{3}}=\frac{1}{120}=0,008(3)$$

# %% [markdown]
# #### 3. В ящике имеется 15 деталей, из которых 9 окрашены. Рабочий случайным образом извлекает 3 детали. Какова вероятность того, что все извлеченные детали окрашены?

# %% [markdown]
# Количество сочетаний из 3-х деталей:
# $$C_{15}^{3}=\frac{15!}{12!*3!}=\frac{13*14*15}{2*3}=13*7*5=455$$

# %% [markdown]
# Количество исходов - все окрашены:
#     $$C_{9}^{3}=\frac{9!}{6!*3!}=\frac{7*8*9}{2*3}=7*4*3=84$$

# %% [markdown]
# Вероятность извлечения трех окрашеных:
# $$P=\frac{C_{9}^{3}}{C_{15}^{3}}=\frac{84}{455}=0,184615385$$

# %% [markdown]
# #### 4. В лотерее 100 билетов. Из них 2 выигрышных. Какова вероятность того, что 2 приобретенных билета окажутся выигрышными?

# %% [markdown]
# Количество сочетаний из двух билетов:
# $$C_{100}^{2}=\frac{100!}{98!*2!}=\frac{99*100}{2}=4950$$

# %% [markdown]
# Вариантов 2 из 2 = 1

# %% [markdown]
# Вероятность 2 выигрышные:
# $$P=\frac{1}{C_{100}^{2}}=\frac{1}{4950}=0,00020202$$
