# %% [markdown]
# ### Задание 3
#
# 1. Задание (в программе)
# Нарисуйте график функции:
# y(x) = k∙cos(x – a) + b
# для некоторых (2-3 различных) значений параметров k, a, b

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
x = np.linspace(-10, 10, 100)
k, a, b = 1, 3, 2
k1, a1, b1 = 4, 2, 1
k2, a2, b2 = -2, 8, 6
plt.plot(x, k * np.cos(x - a) + b, label='k=1; a=3; b=2')
plt.plot(x, k1 * np.cos(x - a1) + b1, label='k=4; a=2; b=1')
plt.plot(x, k2 * np.cos(x - a2) + b2, label='k=-2; a=8; b=6')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# 2. Задание
# Докажите, что при ортогональном преобразовании сохраняется расстояние между точками.

# %%
x1 = 1
x2 = 2
y1 = 4
y2 = 3
xy_len = np.sqrt((x2 - x1)**2 + (y2-y1)**2)
print(xy_len)
# Out:
# 1.4142135623730951

# %%
s = np.pi/2
X1 = x1*np.cos(s) + y1*np.sin(s)
Y1 = - x1*np.sin(s) + y1*np.cos(s)
X2 = x2*np.cos(s) + y2*np.sin(s)
Y2 = - x2*np.sin(s) + y2*np.cos(s)
XY_len = np.sqrt((X2 - X1)**2 + (Y2-Y1)**2)
print(XY_len)
# Out:
# 1.4142135623730951

# %% [markdown]
# 3. Задание (в программе)
# Напишите код, который будет переводить полярные координаты в декартовы.
# Напишите код, который будет рисовать график окружности в полярных координатах.

# %%
s = np.pi/2
R = 10
x = R * np.cos(s)
y = R * np.sin(s)

# %%
rads = np.arange(0, (2*np.pi), 0.01)

for s in rads:
    plt.polar(s, R, '.') 

plt.show()

# %% [markdown]
# 4. Задание (в программе)
#
# Решите систему уравнений:
#
# y = x2 – 1
#
# exp(x) + x∙(1 – y) = 1
#
#
# Решите систему уравнений и неравенств:
#
# y = x2 – 1
#
# exp(x) + x∙(1 – y) > 1

# %%
from scipy.optimize import fsolve

# %%
def equatuins(p):
    x, y = p
    return (y - x**2 + 1, np.exp(x) + x - x*y - 1)

x1, y1 = fsolve(equatuins, (1, 1))
print(x1, y1)
# Out:
# 1.0807145162638894e-13 -0.999999999999867

# %%
def equatuins(p):
    x, y = p
    return (y - x**2 + 1, np.exp(x) + x - x*y - 1.1)

x1, y1 = fsolve(equatuins, (1, 1))
print(x1, y1)
# Out:
# 0.03316017875619974 -0.998900402545825
